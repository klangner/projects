# %% [markdown]
# # Analize data from rtl_power
#
# Column names: `date, time, Hz low, Hz high, Hz step, samples, dB, dB, dB`

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import polars as pl
plt.rcParams["figure.figsize"] = [15, 5]

# %%
df = pd.read_csv("../data/sandbox/sat-137M.csv", header=None)
df = df[df.iloc[:, 2] == 137000000]
df
# Out:
#             0          1          2          3       4     5      6      7     \
# 1     2024-02-04   03:47:20  137000000  139000000  976.56   316 -41.02 -40.81
# 3     2024-02-04   03:47:30  137000000  139000000  976.56   344 -42.87 -43.81
# 5     2024-02-04   03:47:40  137000000  139000000  976.56   344 -41.35 -41.84
# 7     2024-02-04   03:47:50  137000000  139000000  976.56   344 -42.64 -43.40
# 9     2024-02-04   03:48:00  137000000  139000000  976.56   344 -41.81 -42.25
# ...          ...        ...        ...        ...     ...   ...    ...    ...
# 7191  2024-02-04   13:46:30  137000000  139000000  976.56   344 -43.43 -42.98
# 7193  2024-02-04   13:46:40  137000000  139000000  976.56   348 -43.81 -44.18
# 7195  2024-02-04   13:46:50  137000000  139000000  976.56   344 -43.32 -43.29
# 7197  2024-02-04   13:47:00  137000000  139000000  976.56   344 -43.04 -43.84
# 7199  2024-02-04   13:47:10  137000000  139000000  976.56   344 -43.34 -43.84
#
# ...

# %%
noaa15 = df.iloc[:, [1,640]]
plt.plot(noaa15[640])
plt.show()
